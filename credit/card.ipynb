# %%
import pandas as pd
import csv as csv
from sklearn.ensemble import RandomForestClassifier

# Load training data
train_df = pd.read_csv("./input/application_train.csv", header=0)

# %%
 #欠損テーブルの情報を確認する
def kesson_table(df): 
    null_val = df.isnull().sum()
    percent = 100 * df.isnull().sum()/len(df)
    kesson_table = pd.concat([null_val, percent], axis=1)
    kesson_table_ren_columns = kesson_table.rename(
    columns = {0 : '欠損数', 1 : '%'})
    return kesson_table_ren_columns

#train_df = train_df.drop(["FLAG_DOCUMENT_2", "FLAG_DOCUMENT_3", "FLAG_DOCUMENT_4", "FLAG_DOCUMENT_5", "FLAG_DOCUMENT_6", "FLAG_DOCUMENT_7", "FLAG_DOCUMENT_8", "FLAG_DOCUMENT_9", "FLAG_DOCUMENT_10", "FLAG_DOCUMENT_11", "FLAG_DOCUMENT_12", "FLAG_DOCUMENT_13", "FLAG_DOCUMENT_14", "FLAG_DOCUMENT_15", "FLAG_DOCUMENT_16", "FLAG_DOCUMENT_17", "FLAG_DOCUMENT_18", "FLAG_DOCUMENT_19", "FLAG_DOCUMENT_20", "FLAG_DOCUMENT_21"], axis=1)
#train_df = train_df.drop(["OWN_CAR_AGE", "APARTMENTS_MEDI", "BASEMENTAREA_MEDI", "YEARS_BEGINEXPLUATATION_MEDI", "YEARS_BUILD_MEDI", "COMMONAREA_MEDI", "ELEVATORS_MEDI", "ENTRANCES_MEDI", "FLOORSMAX_MEDI", "FLOORSMIN_MEDI", "LANDAREA_MEDI", "LIVINGAPARTMENTS_MEDI", "LIVINGAREA_MEDI", "NONLIVINGAPARTMENTS_MEDI", "NONLIVINGAREA_MEDI", "FONDKAPREMONT_MODE", "HOUSETYPE_MODE", "TOTALAREA_MODE", "WALLSMATERIAL_MODE", "EMERGENCYSTATE_MODE"], axis=1)
#train_df = train_df.drop(["LANDAREA_AVG", "LIVINGAPARTMENTS_AVG", "LIVINGAREA_AVG", "NONLIVINGAPARTMENTS_AVG", "NONLIVINGAREA_AVG", "APARTMENTS_MODE", "BASEMENTAREA_MODE", "YEARS_BEGINEXPLUATATION_MODE", "YEARS_BUILD_MODE", "COMMONAREA_MODE", "ELEVATORS_MODE", "ENTRANCES_MODE", "FLOORSMAX_MODE", "FLOORSMIN_MODE", "LANDAREA_MODE", "LIVINGAPARTMENTS_MODE", "LIVINGAREA_MODE", "NONLIVINGAPARTMENTS_MODE", "NONLIVINGAREA_MODE"], axis=1)
#train_df = train_df.drop(["EXT_SOURCE_1", "APARTMENTS_AVG", "BASEMENTAREA_AVG", "YEARS_BEGINEXPLUATATION_AVG", "YEARS_BUILD_AVG", "COMMONAREA_AVG", "ELEVATORS_AVG", "ENTRANCES_AVG", "FLOORSMAX_AVG", "FLOORSMIN_AVG"], axis=1)
kesson_table(train_df)
# Out:
#                                欠損数          %
# SK_ID_CURR                       0   0.000000
# TARGET                           0   0.000000
# NAME_CONTRACT_TYPE               0   0.000000
# CODE_GENDER                      0   0.000000
# FLAG_OWN_CAR                     0   0.000000
# FLAG_OWN_REALTY                  0   0.000000
# CNT_CHILDREN                     0   0.000000
# AMT_INCOME_TOTAL                 0   0.000000
# AMT_CREDIT                       0   0.000000
# AMT_ANNUITY                     12   0.003902
# AMT_GOODS_PRICE                278   0.090403
# NAME_TYPE_SUITE               1292   0.420148
# NAME_INCOME_TYPE                 0   0.000000
# NAME_EDUCATION_TYPE              0   0.000000
# NAME_FAMILY_STATUS               0   0.000000
# NAME_HOUSING_TYPE                0   0.000000
# REGION_POPULATION_RELATIVE       0   0.000000
# DAYS_BIRTH                       0   0.000000
# DAYS_EMPLOYED                    0   0.000000
# DAYS_REGISTRATION                0   0.000000
# DAYS_ID_PUBLISH                  0   0.000000
# OWN_CAR_AGE                 202929  65.990810
# FLAG_MOBIL                       0   0.000000
# FLAG_EMP_PHONE                   0   0.000000
# FLAG_WORK_PHONE                  0   0.000000
# FLAG_CONT_MOBILE                 0   0.000000
# FLAG_PHONE                       0   0.000000
# FLAG_EMAIL                       0   0.000000
# OCCUPATION_TYPE              96391  31.345545
# CNT_FAM_MEMBERS                  2   0.000650
# ...                            ...        ...
# DEF_30_CNT_SOCIAL_CIRCLE      1021   0.332021
# OBS_60_CNT_SOCIAL_CIRCLE      1021   0.332021
# DEF_60_CNT_SOCIAL_CIRCLE      1021   0.332021
# DAYS_LAST_PHONE_CHANGE           1   0.000325
# FLAG_DOCUMENT_2                  0   0.000000
# FLAG_DOCUMENT_3                  0   0.000000
# FLAG_DOCUMENT_4                  0   0.000000
# FLAG_DOCUMENT_5                  0   0.000000
# FLAG_DOCUMENT_6                  0   0.000000
# FLAG_DOCUMENT_7                  0   0.000000
# FLAG_DOCUMENT_8                  0   0.000000
# FLAG_DOCUMENT_9                  0   0.000000
# FLAG_DOCUMENT_10                 0   0.000000
# FLAG_DOCUMENT_11                 0   0.000000
# FLAG_DOCUMENT_12                 0   0.000000
# FLAG_DOCUMENT_13                 0   0.000000
# FLAG_DOCUMENT_14                 0   0.000000
# FLAG_DOCUMENT_15                 0   0.000000
# FLAG_DOCUMENT_16                 0   0.000000
# FLAG_DOCUMENT_17                 0   0.000000
# FLAG_DOCUMENT_18                 0   0.000000
# FLAG_DOCUMENT_19                 0   0.000000
# FLAG_DOCUMENT_20                 0   0.000000
# FLAG_DOCUMENT_21                 0   0.000000
# AMT_REQ_CREDIT_BUREAU_HOUR   41519  13.501631
# AMT_REQ_CREDIT_BUREAU_DAY    41519  13.501631
# AMT_REQ_CREDIT_BUREAU_WEEK   41519  13.501631
# AMT_REQ_CREDIT_BUREAU_MON    41519  13.501631
# AMT_REQ_CREDIT_BUREAU_QRT    41519  13.501631
# AMT_REQ_CREDIT_BUREAU_YEAR   41519  13.501631
#
# [122 rows x 2 columns]

# %%
pd.value_counts(train_df['NAME_TYPE_SUITE']) 
train_df['NAME_TYPE_SUITE'].value_counts()
train_df.dropna(subset=['NAME_TYPE_SUITE'], inplace = True)
kesson_table(train_df)
# Out:
#                                欠損数          %
# SK_ID_CURR                       0   0.000000
# TARGET                           0   0.000000
# NAME_CONTRACT_TYPE               0   0.000000
# CODE_GENDER                      0   0.000000
# FLAG_OWN_CAR                     0   0.000000
# FLAG_OWN_REALTY                  0   0.000000
# CNT_CHILDREN                     0   0.000000
# AMT_INCOME_TOTAL                 0   0.000000
# AMT_CREDIT                       0   0.000000
# AMT_ANNUITY                     12   0.003919
# AMT_GOODS_PRICE                  0   0.000000
# NAME_TYPE_SUITE                  0   0.000000
# NAME_INCOME_TYPE                 0   0.000000
# NAME_EDUCATION_TYPE              0   0.000000
# NAME_FAMILY_STATUS               0   0.000000
# NAME_HOUSING_TYPE                0   0.000000
# REGION_POPULATION_RELATIVE       0   0.000000
# DAYS_BIRTH                       0   0.000000
# DAYS_EMPLOYED                    0   0.000000
# DAYS_REGISTRATION                0   0.000000
# DAYS_ID_PUBLISH                  0   0.000000
# FLAG_MOBIL                       0   0.000000
# FLAG_EMP_PHONE                   0   0.000000
# FLAG_WORK_PHONE                  0   0.000000
# FLAG_CONT_MOBILE                 0   0.000000
# FLAG_PHONE                       0   0.000000
# FLAG_EMAIL                       0   0.000000
# OCCUPATION_TYPE              96006  31.352072
# CNT_FAM_MEMBERS                  0   0.000000
# REGION_RATING_CLIENT             0   0.000000
# REGION_RATING_CLIENT_W_CITY      0   0.000000
# WEEKDAY_APPR_PROCESS_START       0   0.000000
# HOUR_APPR_PROCESS_START          0   0.000000
# REG_REGION_NOT_LIVE_REGION       0   0.000000
# REG_REGION_NOT_WORK_REGION       0   0.000000
# LIVE_REGION_NOT_WORK_REGION      0   0.000000
# REG_CITY_NOT_LIVE_CITY           0   0.000000
# REG_CITY_NOT_WORK_CITY           0   0.000000
# LIVE_CITY_NOT_WORK_CITY          0   0.000000
# ORGANIZATION_TYPE                0   0.000000
# EXT_SOURCE_2                   659   0.215205
# EXT_SOURCE_3                 60751  19.839069
# OBS_30_CNT_SOCIAL_CIRCLE      1021   0.333422
# DEF_30_CNT_SOCIAL_CIRCLE      1021   0.333422
# OBS_60_CNT_SOCIAL_CIRCLE      1021   0.333422
# DEF_60_CNT_SOCIAL_CIRCLE      1021   0.333422
# DAYS_LAST_PHONE_CHANGE           1   0.000327
# AMT_REQ_CREDIT_BUREAU_HOUR   41410  13.523002
# AMT_REQ_CREDIT_BUREAU_DAY    41410  13.523002
# AMT_REQ_CREDIT_BUREAU_WEEK   41410  13.523002
# AMT_REQ_CREDIT_BUREAU_MON    41410  13.523002
# AMT_REQ_CREDIT_BUREAU_QRT    41410  13.523002
# AMT_REQ_CREDIT_BUREAU_YEAR   41410  13.523002

# %%
train_df['OCCUPATION_TYPE'].value_counts()
# Out:
# Laborers                 54972
# Sales staff              31958
# Core staff               27427
# Managers                 21276
# Drivers                  18521
# High skill tech staff    11327
# Accountants               9769
# Medicine staff            8505
# Security staff            6695
# Cooking staff             5930
# Cleaning staff            4641
# Private service staff     2637
# Low-skill Laborers        2085
# Waiters/barmen staff      1340
# Secretaries               1301
# Realty agents              748
# HR staff                   559
# IT staff                   522
# Name: OCCUPATION_TYPE, dtype: int64

# %%
df_corr = train_df.corr()
# Out:
#                              SK_ID_CURR    TARGET  CNT_CHILDREN  \
# SK_ID_CURR                     1.000000 -0.002148     -0.001272
# TARGET                        -0.002148  1.000000      0.019277
# CNT_CHILDREN                  -0.001272  0.019277      1.000000
# AMT_INCOME_TOTAL              -0.001750 -0.003921      0.012893
# AMT_CREDIT                    -0.000184 -0.030309      0.002090
# AMT_ANNUITY                   -0.000251 -0.012813      0.021478
# AMT_GOODS_PRICE               -0.000195 -0.039581     -0.002028
# REGION_POPULATION_RELATIVE     0.000990 -0.037256     -0.025651
# DAYS_BIRTH                    -0.001597  0.078567      0.331173
# DAYS_EMPLOYED                  0.001401 -0.045061     -0.239856
# DAYS_REGISTRATION             -0.001076  0.042129      0.183458
# DAYS_ID_PUBLISH               -0.000432  0.051528     -0.028030
# OWN_CAR_AGE                    0.001718  0.037603      0.008399
# FLAG_MOBIL                     0.002810  0.000536      0.001044
# FLAG_EMP_PHONE                -0.001370  0.046115      0.240752
# FLAG_WORK_PHONE               -0.000631  0.028601      0.055291
# FLAG_CONT_MOBILE               0.002814  0.000388     -0.000798
# FLAG_PHONE                     0.002723 -0.023794     -0.030096
# FLAG_EMAIL                     0.000192 -0.001707      0.022458
# CNT_FAM_MEMBERS               -0.002951  0.009286      0.879182
# REGION_RATING_CLIENT          -0.001321  0.059074      0.025563
# REGION_RATING_CLIENT_W_CITY   -0.001464  0.061062      0.024884
# HOUR_APPR_PROCESS_START        0.000538 -0.024137     -0.007314
# REG_REGION_NOT_LIVE_REGION    -0.000288  0.005652     -0.013292
# REG_REGION_NOT_WORK_REGION     0.001095  0.006917      0.008112
# LIVE_REGION_NOT_WORK_REGION    0.002923  0.002761      0.014782
# REG_CITY_NOT_LIVE_CITY        -0.001851  0.044678      0.020165
# REG_CITY_NOT_WORK_CITY        -0.001550  0.050983      0.070739
# LIVE_CITY_NOT_WORK_CITY        0.000056  0.032367      0.069938
# EXT_SOURCE_1                   0.000153 -0.155664     -0.138668
# ...                                 ...       ...           ...
# DEF_30_CNT_SOCIAL_CIRCLE      -0.000011  0.032171     -0.001184
# OBS_60_CNT_SOCIAL_CIRCLE      -0.001460  0.009052      0.015301
# DEF_60_CNT_SOCIAL_CIRCLE       0.001286  0.031214     -0.001796
# DAYS_LAST_PHONE_CHANGE        -0.000698  0.055630     -0.005405
# FLAG_DOCUMENT_2                0.000703  0.005422      0.001790
# FLAG_DOCUMENT_3               -0.003397  0.044520      0.056657
# FLAG_DOCUMENT_4               -0.004146 -0.002680     -0.003717
# FLAG_DOCUMENT_5               -0.001968 -0.000226     -0.017842
# FLAG_DOCUMENT_6                0.002165 -0.028560     -0.156683
# FLAG_DOCUMENT_7               -0.002357 -0.001492     -0.001500
# FLAG_DOCUMENT_8                0.001925 -0.008133      0.051967
# FLAG_DOCUMENT_9                0.001849 -0.004523     -0.002487
# FLAG_DOCUMENT_10              -0.000107 -0.001313     -0.002556
# FLAG_DOCUMENT_11              -0.001914 -0.003887     -0.005221
# FLAG_DOCUMENT_12              -0.001047 -0.000758      0.000294
# FLAG_DOCUMENT_13               0.000879 -0.011580      0.003808
# FLAG_DOCUMENT_14              -0.000984 -0.009840     -0.005405
# FLAG_DOCUMENT_15               0.002151 -0.006052      0.003596
# FLAG_DOCUMENT_16              -0.000578 -0.011769      0.009887
# FLAG_DOCUMENT_17               0.000995 -0.003312      0.000459
# FLAG_DOCUMENT_18               0.000009 -0.007826      0.003219
# FLAG_DOCUMENT_19               0.000357 -0.001578      0.000572
# FLAG_DOCUMENT_20               0.000683  0.000428      0.001025
# FLAG_DOCUMENT_21               0.000350  0.003850     -0.002520
# AMT_REQ_CREDIT_BUREAU_HOUR    -0.002708  0.000872     -0.000122
# AMT_REQ_CREDIT_BUREAU_DAY     -0.002467  0.002819     -0.000109
# AMT_REQ_CREDIT_BUREAU_WEEK     0.002057  0.000805     -0.002276
# AMT_REQ_CREDIT_BUREAU_MON      0.000655 -0.012551     -0.010930
# AMT_REQ_CREDIT_BUREAU_QRT      0.000937 -0.002035     -0.007717
# AMT_REQ_CREDIT_BUREAU_YEAR     0.004486  0.019731     -0.041729
#
#                              AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# SK_ID_CURR                          -0.001750   -0.000184    -0.000251
# TARGET                              -0.003921   -0.030309    -0.012813
# CNT_CHILDREN                         0.012893    0.002090     0.021478
# AMT_INCOME_TOTAL                     1.000000    0.156154     0.191061
# AMT_CREDIT                           0.156154    1.000000     0.769937
# AMT_ANNUITY                          0.191061    0.769937     1.000000
# AMT_GOODS_PRICE                      0.159050    0.986975     0.775089
# REGION_POPULATION_RELATIVE           0.074511    0.099497     0.118176
# DAYS_BIRTH                           0.027170   -0.056325     0.009496
# DAYS_EMPLOYED                       -0.064089   -0.066039    -0.104056
# DAYS_REGISTRATION                    0.027565    0.009064     0.038464
# DAYS_ID_PUBLISH                      0.008503   -0.006504     0.011451
# OWN_CAR_AGE                         -0.117166   -0.093721    -0.097074
# FLAG_MOBIL                           0.000326    0.001439     0.000151
# FLAG_EMP_PHONE                       0.063859    0.064711     0.103256
# FLAG_WORK_PHONE                     -0.016945   -0.020385    -0.024031
# FLAG_CONT_MOBILE                    -0.008296    0.023709     0.022442
# FLAG_PHONE                           0.000215    0.026943     0.011509
# FLAG_EMAIL                           0.038382    0.016914     0.071948
# CNT_FAM_MEMBERS                      0.016284    0.063149     0.075596
# REGION_RATING_CLIENT                -0.085184   -0.101498    -0.128393
# REGION_RATING_CLIENT_W_CITY         -0.091471   -0.110701    -0.141590
# HOUR_APPR_PROCESS_START              0.036362    0.052481     0.052238
# REG_REGION_NOT_LIVE_REGION           0.031138    0.024088     0.041302
# REG_REGION_NOT_WORK_REGION           0.062074    0.051577     0.079242
# LIVE_REGION_NOT_WORK_REGION          0.057779    0.052176     0.074368
# REG_CITY_NOT_LIVE_CITY               0.003667   -0.026763    -0.006058
# REG_CITY_NOT_WORK_CITY               0.006489   -0.018961     0.000885
# LIVE_CITY_NOT_WORK_CITY              0.008306   -0.000067     0.010050
# EXT_SOURCE_1                         0.026212    0.168863     0.119282
# ...                                       ...         ...          ...
# DEF_30_CNT_SOCIAL_CIRCLE            -0.013173   -0.021054    -0.022761
# OBS_60_CNT_SOCIAL_CIRCLE            -0.012960    0.000253    -0.011655
# DEF_60_CNT_SOCIAL_CIRCLE            -0.013064   -0.023583    -0.023895
# DAYS_LAST_PHONE_CHANGE              -0.018721   -0.075043    -0.064045
# FLAG_DOCUMENT_2                     -0.001000    0.008939     0.003399
# FLAG_DOCUMENT_3                     -0.016955    0.095674     0.102215
# FLAG_DOCUMENT_4                      0.000529    0.000638     0.001103
# FLAG_DOCUMENT_5                      0.002117   -0.008766    -0.003295
# FLAG_DOCUMENT_6                     -0.045750   -0.045829    -0.073276
# FLAG_DOCUMENT_7                      0.005531   -0.001595     0.000820
# FLAG_DOCUMENT_8                      0.072294    0.082765     0.130695
# FLAG_DOCUMENT_9                      0.018134    0.021528     0.033057
# FLAG_DOCUMENT_10                     0.000419   -0.002630    -0.002787
# FLAG_DOCUMENT_11                     0.002290    0.028212    -0.004339
# FLAG_DOCUMENT_12                     0.002542    0.003871     0.000847
# FLAG_DOCUMENT_13                     0.022540    0.051411     0.024648
# FLAG_DOCUMENT_14                     0.020363    0.048013     0.036473
# FLAG_DOCUMENT_15                     0.010222    0.030986     0.014667
# FLAG_DOCUMENT_16                     0.006945    0.060664     0.007369
# FLAG_DOCUMENT_17                     0.002299    0.010763     0.002619
# FLAG_DOCUMENT_18                     0.003036    0.033760    -0.009635
# FLAG_DOCUMENT_19                     0.002432    0.020745     0.004571
# FLAG_DOCUMENT_20                     0.000352    0.029989     0.011175
# FLAG_DOCUMENT_21                    -0.000543   -0.016018    -0.017436
# AMT_REQ_CREDIT_BUREAU_HOUR           0.000812   -0.003674     0.004074
# AMT_REQ_CREDIT_BUREAU_DAY            0.002979    0.003855     0.001993
# AMT_REQ_CREDIT_BUREAU_WEEK           0.002336   -0.001573     0.013641
# AMT_REQ_CREDIT_BUREAU_MON            0.024564    0.054273     0.038885
# AMT_REQ_CREDIT_BUREAU_QRT            0.004883    0.016261     0.010257
# AMT_REQ_CREDIT_BUREAU_YEAR           0.011794   -0.047545    -0.011216
#
#                              AMT_GOODS_PRICE  REGION_POPULATION_RELATIVE  \
# SK_ID_CURR                         -0.000195                    0.000990
# TARGET                             -0.039581                   -0.037256
# CNT_CHILDREN                       -0.002028                   -0.025651
# AMT_INCOME_TOTAL                    0.159050                    0.074511
# AMT_CREDIT                          0.986975                    0.099497
# AMT_ANNUITY                         0.775089                    0.118176
# AMT_GOODS_PRICE                     1.000000                    0.103417
# REGION_POPULATION_RELATIVE          0.103417                    1.000000
# DAYS_BIRTH                         -0.054611                   -0.029583
# DAYS_EMPLOYED                      -0.063883                   -0.004194
# DAYS_REGISTRATION                   0.011000                   -0.053959
# DAYS_ID_PUBLISH                    -0.009295                   -0.003911
# OWN_CAR_AGE                        -0.103296                   -0.081560
# FLAG_MOBIL                          0.001401                    0.001336
# FLAG_EMP_PHONE                      0.062519                    0.004257
# FLAG_WORK_PHONE                     0.000819                   -0.015497
# FLAG_CONT_MOBILE                    0.020717                   -0.012513
# FLAG_PHONE                          0.042182                    0.090970
# FLAG_EMAIL                          0.017280                    0.040092
# CNT_FAM_MEMBERS                     0.061089                   -0.024257
# REGION_RATING_CLIENT               -0.103540                   -0.532800
# REGION_RATING_CLIENT_W_CITY        -0.112048                   -0.531470
# HOUR_APPR_PROCESS_START             0.062035                    0.171124
# REG_REGION_NOT_LIVE_REGION          0.026234                    0.002051
# REG_REGION_NOT_WORK_REGION          0.052852                    0.056703
# LIVE_REGION_NOT_WORK_REGION         0.052434                    0.080838
# REG_CITY_NOT_LIVE_CITY             -0.027102                   -0.050582
# REG_CITY_NOT_WORK_CITY             -0.020551                   -0.044154
# LIVE_CITY_NOT_WORK_CITY            -0.001589                   -0.015225
# EXT_SOURCE_1                        0.176078                    0.099891
# ...                                      ...                         ...
# DEF_30_CNT_SOCIAL_CIRCLE           -0.022103                    0.006311
# OBS_60_CNT_SOCIAL_CIRCLE            0.000371                   -0.010830
# DEF_60_CNT_SOCIAL_CIRCLE           -0.024363                    0.002431
# DAYS_LAST_PHONE_CHANGE             -0.077560                   -0.044338
# FLAG_DOCUMENT_2                     0.010815                   -0.003045
# FLAG_DOCUMENT_3                     0.074819                   -0.084557
# FLAG_DOCUMENT_4                     0.001128                    0.008122
# FLAG_DOCUMENT_5                    -0.005039                    0.016655
# FLAG_DOCUMENT_6                    -0.049212                    0.000366
# FLAG_DOCUMENT_7                     0.000217                    0.004246
# FLAG_DOCUMENT_8                     0.080523                    0.088477
# FLAG_DOCUMENT_9                     0.021299                    0.037948
# FLAG_DOCUMENT_10                   -0.002135                    0.002308
# FLAG_DOCUMENT_11                    0.034276                    0.024216
# FLAG_DOCUMENT_12                    0.004082                   -0.000404
# FLAG_DOCUMENT_13                    0.051302                    0.031216
# FLAG_DOCUMENT_14                    0.048211                    0.030340
# FLAG_DOCUMENT_15                    0.031611                    0.008355
# FLAG_DOCUMENT_16                    0.057237                    0.006121
# FLAG_DOCUMENT_17                    0.011204                    0.007317
# FLAG_DOCUMENT_18                    0.032343                    0.013321
# FLAG_DOCUMENT_19                    0.019948                    0.002876
# FLAG_DOCUMENT_20                    0.030619                   -0.000324
# FLAG_DOCUMENT_21                   -0.014509                    0.003361
# AMT_REQ_CREDIT_BUREAU_HOUR         -0.002993                   -0.002381
# AMT_REQ_CREDIT_BUREAU_DAY           0.004319                    0.001142
# AMT_REQ_CREDIT_BUREAU_WEEK         -0.001287                   -0.002273
# AMT_REQ_CREDIT_BUREAU_MON           0.056344                    0.078450
# AMT_REQ_CREDIT_BUREAU_QRT           0.016770                   -0.001102
# AMT_REQ_CREDIT_BUREAU_YEAR         -0.050002                    0.001240
#
#                              DAYS_BIRTH  DAYS_EMPLOYED  \
# SK_ID_CURR                    -0.001597       0.001401
# TARGET                         0.078567      -0.045061
# CNT_CHILDREN                   0.331173      -0.239856
# AMT_INCOME_TOTAL               0.027170      -0.064089
# AMT_CREDIT                    -0.056325      -0.066039
# AMT_ANNUITY                    0.009496      -0.104056
# AMT_GOODS_PRICE               -0.054611      -0.063883
# REGION_POPULATION_RELATIVE    -0.029583      -0.004194
# DAYS_BIRTH                     1.000000      -0.615738
# DAYS_EMPLOYED                 -0.615738       1.000000
# DAYS_REGISTRATION              0.331839      -0.210028
# DAYS_ID_PUBLISH                0.272572      -0.272526
# OWN_CAR_AGE                    0.006323       0.028318
# FLAG_MOBIL                    -0.003093       0.000820
# FLAG_EMP_PHONE                 0.619759      -0.999755
# FLAG_WORK_PHONE                0.172265      -0.233841
# FLAG_CONT_MOBILE              -0.015056       0.012782
# FLAG_PHONE                    -0.042605       0.015401
# FLAG_EMAIL                     0.088332      -0.062138
# CNT_FAM_MEMBERS                0.279105      -0.233489
# REGION_RATING_CLIENT           0.009474       0.032789
# REGION_RATING_CLIENT_W_CITY    0.008147       0.034735
# HOUR_APPR_PROCESS_START        0.090826      -0.090937
# REG_REGION_NOT_LIVE_REGION     0.065767      -0.035998
# REG_REGION_NOT_WORK_REGION     0.095916      -0.107169
# LIVE_REGION_NOT_WORK_REGION    0.069623      -0.095526
# REG_CITY_NOT_LIVE_CITY         0.180403      -0.090607
# REG_CITY_NOT_WORK_CITY         0.242510      -0.254689
# LIVE_CITY_NOT_WORK_CITY        0.159009      -0.218222
# EXT_SOURCE_1                  -0.600721       0.290076
# ...                                 ...            ...
# DEF_30_CNT_SOCIAL_CIRCLE       0.000274       0.016722
# OBS_60_CNT_SOCIAL_CIRCLE       0.007048       0.005915
# DEF_60_CNT_SOCIAL_CIRCLE       0.001925       0.014152
# DAYS_LAST_PHONE_CHANGE         0.083027       0.023117
# FLAG_DOCUMENT_2               -0.001189      -0.003098
# FLAG_DOCUMENT_3                0.109067      -0.248306
# FLAG_DOCUMENT_4               -0.002788       0.000435
# FLAG_DOCUMENT_5                0.015820      -0.019322
# FLAG_DOCUMENT_6               -0.406204       0.596154
# FLAG_DOCUMENT_7                0.001590      -0.002698
# FLAG_DOCUMENT_8                0.113262      -0.121523
# FLAG_DOCUMENT_9                0.017694      -0.023640
# FLAG_DOCUMENT_10              -0.000614      -0.000138
# FLAG_DOCUMENT_11               0.044390      -0.028659
# FLAG_DOCUMENT_12               0.000239      -0.001228
# FLAG_DOCUMENT_13               0.025715      -0.025279
# FLAG_DOCUMENT_14               0.029859      -0.022779
# FLAG_DOCUMENT_15               0.012894      -0.013654
# FLAG_DOCUMENT_16               0.023376      -0.041544
# FLAG_DOCUMENT_17               0.007797      -0.007101
# FLAG_DOCUMENT_18               0.043662      -0.039535
# FLAG_DOCUMENT_19               0.002968      -0.009791
# FLAG_DOCUMENT_20               0.008424      -0.009984
# FLAG_DOCUMENT_21               0.027112      -0.008334
# AMT_REQ_CREDIT_BUREAU_HOUR     0.005654      -0.005023
# AMT_REQ_CREDIT_BUREAU_DAY      0.002668       0.000400
# AMT_REQ_CREDIT_BUREAU_WEEK    -0.001177       0.003137
# AMT_REQ_CREDIT_BUREAU_MON      0.001426      -0.034531
# AMT_REQ_CREDIT_BUREAU_QRT     -0.011695       0.015279
# AMT_REQ_CREDIT_BUREAU_YEAR    -0.071853       0.049857
#
#                                         ...              FLAG_DOCUMENT_18  \
# SK_ID_CURR                              ...                      0.000009
# TARGET                                  ...                     -0.007826
# CNT_CHILDREN                            ...                      0.003219
# AMT_INCOME_TOTAL                        ...                      0.003036
# AMT_CREDIT                              ...                      0.033760
# AMT_ANNUITY                             ...                     -0.009635
# AMT_GOODS_PRICE                         ...                      0.032343
# REGION_POPULATION_RELATIVE              ...                      0.013321
# DAYS_BIRTH                              ...                      0.043662
# DAYS_EMPLOYED                           ...                     -0.039535
# DAYS_REGISTRATION                       ...                      0.015930
# DAYS_ID_PUBLISH                         ...                      0.014032
# OWN_CAR_AGE                             ...                     -0.010794
# FLAG_MOBIL                              ...                     -0.020358
# FLAG_EMP_PHONE                          ...                      0.039692
# FLAG_WORK_PHONE                         ...                      0.033100
# FLAG_CONT_MOBILE                        ...                     -0.044158
# FLAG_PHONE                              ...                      0.004442
# FLAG_EMAIL                              ...                     -0.008165
# CNT_FAM_MEMBERS                         ...                      0.000905
# REGION_RATING_CLIENT                    ...                     -0.012525
# REGION_RATING_CLIENT_W_CITY             ...                     -0.013772
# HOUR_APPR_PROCESS_START                 ...                      0.021666
# REG_REGION_NOT_LIVE_REGION              ...                      0.008102
# REG_REGION_NOT_WORK_REGION              ...                      0.007350
# LIVE_REGION_NOT_WORK_REGION             ...                      0.004463
# REG_CITY_NOT_LIVE_CITY                  ...                      0.013244
# REG_CITY_NOT_WORK_CITY                  ...                      0.014017
# LIVE_CITY_NOT_WORK_CITY                 ...                      0.006573
# EXT_SOURCE_1                            ...                     -0.025176
# ...                                     ...                           ...
# DEF_30_CNT_SOCIAL_CIRCLE                ...                     -0.000854
# OBS_60_CNT_SOCIAL_CIRCLE                ...                      0.002424
# DEF_60_CNT_SOCIAL_CIRCLE                ...                     -0.003122
# DAYS_LAST_PHONE_CHANGE                  ...                      0.047005
# FLAG_DOCUMENT_2                         ...                     -0.000578
# FLAG_DOCUMENT_3                         ...                      0.007435
# FLAG_DOCUMENT_4                         ...                     -0.000802
# FLAG_DOCUMENT_5                         ...                     -0.010232
# FLAG_DOCUMENT_6                         ...                     -0.023226
# FLAG_DOCUMENT_7                         ...                     -0.001052
# FLAG_DOCUMENT_8                         ...                      0.006412
# FLAG_DOCUMENT_9                         ...                      0.001661
# FLAG_DOCUMENT_10                        ...                     -0.000393
# FLAG_DOCUMENT_11                        ...                     -0.005512
# FLAG_DOCUMENT_12                        ...                     -0.000227
# FLAG_DOCUMENT_13                        ...                     -0.005189
# FLAG_DOCUMENT_14                        ...                     -0.004708
# FLAG_DOCUMENT_15                        ...                     -0.002986
# FLAG_DOCUMENT_16                        ...                     -0.008649
# FLAG_DOCUMENT_17                        ...                     -0.001435
# FLAG_DOCUMENT_18                        ...                      1.000000
# FLAG_DOCUMENT_19                        ...                     -0.002123
# FLAG_DOCUMENT_20                        ...                      0.083207
# FLAG_DOCUMENT_21                        ...                      0.006556
# AMT_REQ_CREDIT_BUREAU_HOUR              ...                     -0.002443
# AMT_REQ_CREDIT_BUREAU_DAY               ...                      0.013948
# AMT_REQ_CREDIT_BUREAU_WEEK              ...                     -0.004269
# AMT_REQ_CREDIT_BUREAU_MON               ...                     -0.001180
# AMT_REQ_CREDIT_BUREAU_QRT               ...                     -0.005298
# AMT_REQ_CREDIT_BUREAU_YEAR              ...                     -0.046899
#
#                              FLAG_DOCUMENT_19  FLAG_DOCUMENT_20  \
# SK_ID_CURR                           0.000357          0.000683
# TARGET                              -0.001578          0.000428
# CNT_CHILDREN                         0.000572          0.001025
# AMT_INCOME_TOTAL                     0.002432          0.000352
# AMT_CREDIT                           0.020745          0.029989
# AMT_ANNUITY                          0.004571          0.011175
# AMT_GOODS_PRICE                      0.019948          0.030619
# REGION_POPULATION_RELATIVE           0.002876         -0.000324
# DAYS_BIRTH                           0.002968          0.008424
# DAYS_EMPLOYED                       -0.009791         -0.009984
# DAYS_REGISTRATION                    0.004386          0.006952
# DAYS_ID_PUBLISH                      0.001138          0.000168
# OWN_CAR_AGE                         -0.005202         -0.007940
# FLAG_MOBIL                           0.000043          0.000040
# FLAG_EMP_PHONE                       0.009790          0.010032
# FLAG_WORK_PHONE                      0.011349          0.001821
# FLAG_CONT_MOBILE                    -0.005282          0.000963
# FLAG_PHONE                           0.010297          0.000852
# FLAG_EMAIL                          -0.002326         -0.001637
# CNT_FAM_MEMBERS                      0.001690          0.000312
# REGION_RATING_CLIENT                -0.001130          0.002327
# REGION_RATING_CLIENT_W_CITY         -0.001505          0.002698
# HOUR_APPR_PROCESS_START              0.002349          0.003406
# REG_REGION_NOT_LIVE_REGION          -0.001849         -0.002756
# REG_REGION_NOT_WORK_REGION           0.001319         -0.001115
# LIVE_REGION_NOT_WORK_REGION          0.003386         -0.000099
# REG_CITY_NOT_LIVE_CITY              -0.004927         -0.001536
# REG_CITY_NOT_WORK_CITY              -0.004327          0.000767
# LIVE_CITY_NOT_WORK_CITY             -0.002645          0.001487
# EXT_SOURCE_1                         0.005084         -0.004905
# ...                                       ...               ...
# DEF_30_CNT_SOCIAL_CIRCLE            -0.003399          0.000445
# OBS_60_CNT_SOCIAL_CIRCLE             0.000586          0.000303
# DEF_60_CNT_SOCIAL_CIRCLE            -0.003213          0.000365
# DAYS_LAST_PHONE_CHANGE               0.006576          0.008673
# FLAG_DOCUMENT_2                     -0.000156         -0.000145
# FLAG_DOCUMENT_3                      0.008935          0.007041
# FLAG_DOCUMENT_4                     -0.000216         -0.000201
# FLAG_DOCUMENT_5                     -0.002922         -0.002714
# FLAG_DOCUMENT_6                     -0.004525         -0.005854
# FLAG_DOCUMENT_7                     -0.000283         -0.000263
# FLAG_DOCUMENT_8                      0.000383          0.004153
# FLAG_DOCUMENT_9                     -0.001487         -0.001381
# FLAG_DOCUMENT_10                    -0.000106         -0.000098
# FLAG_DOCUMENT_11                    -0.001485         -0.001379
# FLAG_DOCUMENT_12                    -0.000061         -0.000057
# FLAG_DOCUMENT_13                    -0.001398          0.039097
# FLAG_DOCUMENT_14                    -0.001268          0.032196
# FLAG_DOCUMENT_15                    -0.000804          0.029903
# FLAG_DOCUMENT_16                    -0.002330          0.084702
# FLAG_DOCUMENT_17                    -0.000387          0.017845
# FLAG_DOCUMENT_18                    -0.002123          0.083207
# FLAG_DOCUMENT_19                     1.000000          0.036398
# FLAG_DOCUMENT_20                     0.036398          1.000000
# FLAG_DOCUMENT_21                    -0.000434          0.007697
# AMT_REQ_CREDIT_BUREAU_HOUR           0.003627         -0.001815
# AMT_REQ_CREDIT_BUREAU_DAY            0.001228         -0.000068
# AMT_REQ_CREDIT_BUREAU_WEEK          -0.001134         -0.001680
# AMT_REQ_CREDIT_BUREAU_MON           -0.002823          0.001015
# AMT_REQ_CREDIT_BUREAU_QRT           -0.001452         -0.000969
# AMT_REQ_CREDIT_BUREAU_YEAR          -0.007367         -0.011765
#
#                              FLAG_DOCUMENT_21  AMT_REQ_CREDIT_BUREAU_HOUR  \
# SK_ID_CURR                           0.000350                   -0.002708
# TARGET                               0.003850                    0.000872
# CNT_CHILDREN                        -0.002520                   -0.000122
# AMT_INCOME_TOTAL                    -0.000543                    0.000812
# AMT_CREDIT                          -0.016018                   -0.003674
# AMT_ANNUITY                         -0.017436                    0.004074
# AMT_GOODS_PRICE                     -0.014509                   -0.002993
# REGION_POPULATION_RELATIVE           0.003361                   -0.002381
# DAYS_BIRTH                           0.027112                    0.005654
# DAYS_EMPLOYED                       -0.008334                   -0.005023
# DAYS_REGISTRATION                    0.003848                   -0.002826
# DAYS_ID_PUBLISH                      0.017312                    0.004812
# OWN_CAR_AGE                          0.001216                   -0.000065
# FLAG_MOBIL                           0.000033                         NaN
# FLAG_EMP_PHONE                       0.008517                    0.004905
# FLAG_WORK_PHONE                      0.000853                   -0.005198
# FLAG_CONT_MOBILE                    -0.015844                   -0.004620
# FLAG_PHONE                          -0.000544                   -0.003308
# FLAG_EMAIL                          -0.000572                    0.003496
# CNT_FAM_MEMBERS                     -0.005813                    0.000984
# REGION_RATING_CLIENT                -0.001877                    0.006638
# REGION_RATING_CLIENT_W_CITY         -0.001501                    0.006554
# HOUR_APPR_PROCESS_START              0.003950                   -0.016398
# REG_REGION_NOT_LIVE_REGION           0.005105                   -0.002003
# REG_REGION_NOT_WORK_REGION          -0.000922                   -0.001633
# LIVE_REGION_NOT_WORK_REGION         -0.001915                   -0.000879
# REG_CITY_NOT_LIVE_CITY               0.002751                    0.000531
# REG_CITY_NOT_WORK_CITY               0.003297                    0.000534
# LIVE_CITY_NOT_WORK_CITY              0.004151                   -0.000825
# EXT_SOURCE_1                        -0.019255                   -0.004057
# ...                                       ...                         ...
# DEF_30_CNT_SOCIAL_CIRCLE            -0.000543                   -0.000422
# OBS_60_CNT_SOCIAL_CIRCLE            -0.000796                    0.000480
# DEF_60_CNT_SOCIAL_CIRCLE             0.000499                   -0.001453
# DAYS_LAST_PHONE_CHANGE               0.010028                   -0.000903
# FLAG_DOCUMENT_2                     -0.000118                         NaN
# FLAG_DOCUMENT_3                     -0.025684                   -0.000470
# FLAG_DOCUMENT_4                     -0.000164                   -0.000726
# FLAG_DOCUMENT_5                     -0.000726                   -0.001112
# FLAG_DOCUMENT_6                     -0.005637                   -0.002001
# FLAG_DOCUMENT_7                     -0.000215                   -0.000901
# FLAG_DOCUMENT_8                     -0.001458                    0.004857
# FLAG_DOCUMENT_9                     -0.001130                   -0.002417
# FLAG_DOCUMENT_10                    -0.000080                   -0.000363
# FLAG_DOCUMENT_11                    -0.001128                   -0.002837
# FLAG_DOCUMENT_12                    -0.000046                    0.016190
# FLAG_DOCUMENT_13                     0.005112                   -0.001714
# FLAG_DOCUMENT_14                     0.002437                    0.000606
# FLAG_DOCUMENT_15                    -0.000611                   -0.001404
# FLAG_DOCUMENT_16                     0.003820                   -0.001839
# FLAG_DOCUMENT_17                    -0.000294                   -0.001266
# FLAG_DOCUMENT_18                     0.006556                   -0.002443
# FLAG_DOCUMENT_19                    -0.000434                    0.003627
# FLAG_DOCUMENT_20                     0.007697                   -0.001815
# FLAG_DOCUMENT_21                     1.000000                   -0.001350
# AMT_REQ_CREDIT_BUREAU_HOUR          -0.001350                    1.000000
# AMT_REQ_CREDIT_BUREAU_DAY           -0.001119                    0.230562
# AMT_REQ_CREDIT_BUREAU_WEEK          -0.000895                    0.004779
# AMT_REQ_CREDIT_BUREAU_MON           -0.003544                    0.000107
# AMT_REQ_CREDIT_BUREAU_QRT           -0.002161                   -0.002583
# AMT_REQ_CREDIT_BUREAU_YEAR          -0.005480                   -0.004398
#
#                              AMT_REQ_CREDIT_BUREAU_DAY  \
# SK_ID_CURR                                   -0.002467
# TARGET                                        0.002819
# CNT_CHILDREN                                 -0.000109
# AMT_INCOME_TOTAL                              0.002979
# AMT_CREDIT                                    0.003855
# AMT_ANNUITY                                   0.001993
# AMT_GOODS_PRICE                               0.004319
# REGION_POPULATION_RELATIVE                    0.001142
# DAYS_BIRTH                                    0.002668
# DAYS_EMPLOYED                                 0.000400
# DAYS_REGISTRATION                            -0.000201
# DAYS_ID_PUBLISH                              -0.000958
# OWN_CAR_AGE                                  -0.008122
# FLAG_MOBIL                                         NaN
# FLAG_EMP_PHONE                               -0.000360
# FLAG_WORK_PHONE                              -0.004199
# FLAG_CONT_MOBILE                             -0.002500
# FLAG_PHONE                                   -0.000596
# FLAG_EMAIL                                    0.003957
# CNT_FAM_MEMBERS                              -0.001007
# REGION_RATING_CLIENT                         -0.001825
# REGION_RATING_CLIENT_W_CITY                  -0.001544
# HOUR_APPR_PROCESS_START                       0.001847
# REG_REGION_NOT_LIVE_REGION                   -0.001305
# REG_REGION_NOT_WORK_REGION                   -0.002464
# LIVE_REGION_NOT_WORK_REGION                  -0.001763
# REG_CITY_NOT_LIVE_CITY                       -0.002163
# REG_CITY_NOT_WORK_CITY                       -0.002248
# LIVE_CITY_NOT_WORK_CITY                      -0.002222
# EXT_SOURCE_1                                 -0.005585
# ...                                                ...
# DEF_30_CNT_SOCIAL_CIRCLE                     -0.001213
# OBS_60_CNT_SOCIAL_CIRCLE                     -0.002441
# DEF_60_CNT_SOCIAL_CIRCLE                     -0.001709
# DAYS_LAST_PHONE_CHANGE                        0.002429
# FLAG_DOCUMENT_2                                    NaN
# FLAG_DOCUMENT_3                               0.000937
# FLAG_DOCUMENT_4                              -0.000602
# FLAG_DOCUMENT_5                              -0.000367
# FLAG_DOCUMENT_6                               0.003461
# FLAG_DOCUMENT_7                              -0.000747
# FLAG_DOCUMENT_8                               0.000959
# FLAG_DOCUMENT_9                               0.000093
# FLAG_DOCUMENT_10                             -0.000301
# FLAG_DOCUMENT_11                              0.004072
# FLAG_DOCUMENT_12                              0.012264
# FLAG_DOCUMENT_13                              0.006777
# FLAG_DOCUMENT_14                              0.013678
# FLAG_DOCUMENT_15                              0.000690
# FLAG_DOCUMENT_16                              0.006954
# FLAG_DOCUMENT_17                             -0.001050
# FLAG_DOCUMENT_18                              0.013948
# FLAG_DOCUMENT_19                              0.001228
# FLAG_DOCUMENT_20                             -0.000068
# FLAG_DOCUMENT_21                             -0.001119
# AMT_REQ_CREDIT_BUREAU_HOUR                    0.230562
# AMT_REQ_CREDIT_BUREAU_DAY                     1.000000
# AMT_REQ_CREDIT_BUREAU_WEEK                    0.214531
# AMT_REQ_CREDIT_BUREAU_MON                    -0.005183
# AMT_REQ_CREDIT_BUREAU_QRT                    -0.004312
# AMT_REQ_CREDIT_BUREAU_YEAR                   -0.003188
#
#                              AMT_REQ_CREDIT_BUREAU_WEEK  \
# SK_ID_CURR                                     0.002057
# TARGET                                         0.000805
# CNT_CHILDREN                                  -0.002276
# AMT_INCOME_TOTAL                               0.002336
# AMT_CREDIT                                    -0.001573
# AMT_ANNUITY                                    0.013641
# AMT_GOODS_PRICE                               -0.001287
# REGION_POPULATION_RELATIVE                    -0.002273
# DAYS_BIRTH                                    -0.001177
# DAYS_EMPLOYED                                  0.003137
# DAYS_REGISTRATION                             -0.000932
# DAYS_ID_PUBLISH                               -0.001303
# OWN_CAR_AGE                                    0.001887
# FLAG_MOBIL                                          NaN
# FLAG_EMP_PHONE                                -0.003089
# FLAG_WORK_PHONE                               -0.004409
# FLAG_CONT_MOBILE                              -0.008492
# FLAG_PHONE                                    -0.000135
# FLAG_EMAIL                                     0.021662
# CNT_FAM_MEMBERS                               -0.001093
# REGION_RATING_CLIENT                           0.001849
# REGION_RATING_CLIENT_W_CITY                    0.001267
# HOUR_APPR_PROCESS_START                       -0.003222
# REG_REGION_NOT_LIVE_REGION                     0.001250
# REG_REGION_NOT_WORK_REGION                    -0.000945
# LIVE_REGION_NOT_WORK_REGION                   -0.001754
# REG_CITY_NOT_LIVE_CITY                        -0.001409
# REG_CITY_NOT_WORK_CITY                        -0.002810
# LIVE_CITY_NOT_WORK_CITY                       -0.003443
# EXT_SOURCE_1                                  -0.001992
# ...                                                 ...
# DEF_30_CNT_SOCIAL_CIRCLE                      -0.002189
# OBS_60_CNT_SOCIAL_CIRCLE                       0.000122
# DEF_60_CNT_SOCIAL_CIRCLE                      -0.002549
# DAYS_LAST_PHONE_CHANGE                        -0.003130
# FLAG_DOCUMENT_2                                     NaN
# FLAG_DOCUMENT_3                                0.008013
# FLAG_DOCUMENT_4                               -0.001601
# FLAG_DOCUMENT_5                                0.002193
# FLAG_DOCUMENT_6                                0.003001
# FLAG_DOCUMENT_7                               -0.000428
# FLAG_DOCUMENT_8                                0.000775
# FLAG_DOCUMENT_9                                0.000084
# FLAG_DOCUMENT_10                              -0.000801
# FLAG_DOCUMENT_11                              -0.000101
# FLAG_DOCUMENT_12                              -0.000462
# FLAG_DOCUMENT_13                              -0.003951
# FLAG_DOCUMENT_14                              -0.000436
# FLAG_DOCUMENT_15                               0.000368
# FLAG_DOCUMENT_16                              -0.009422
# FLAG_DOCUMENT_17                              -0.002793
# FLAG_DOCUMENT_18                              -0.004269
# FLAG_DOCUMENT_19                              -0.001134
# FLAG_DOCUMENT_20                              -0.001680
# FLAG_DOCUMENT_21                              -0.000895
# AMT_REQ_CREDIT_BUREAU_HOUR                     0.004779
# AMT_REQ_CREDIT_BUREAU_DAY                      0.214531
# AMT_REQ_CREDIT_BUREAU_WEEK                     1.000000
# AMT_REQ_CREDIT_BUREAU_MON                     -0.014203
# AMT_REQ_CREDIT_BUREAU_QRT                     -0.015142
# AMT_REQ_CREDIT_BUREAU_YEAR                     0.018862
#
#                              AMT_REQ_CREDIT_BUREAU_MON  \
# SK_ID_CURR                                    0.000655
# TARGET                                       -0.012551
# CNT_CHILDREN                                 -0.010930
# AMT_INCOME_TOTAL                              0.024564
# AMT_CREDIT                                    0.054273
# AMT_ANNUITY                                   0.038885
# AMT_GOODS_PRICE                               0.056344
# REGION_POPULATION_RELATIVE                    0.078450
# DAYS_BIRTH                                    0.001426
# DAYS_EMPLOYED                                -0.034531
# DAYS_REGISTRATION                            -0.011456
# DAYS_ID_PUBLISH                              -0.009826
# OWN_CAR_AGE                                  -0.021827
# FLAG_MOBIL                                         NaN
# FLAG_EMP_PHONE                                0.034165
# FLAG_WORK_PHONE                              -0.001756
# FLAG_CONT_MOBILE                              0.005949
# FLAG_PHONE                                    0.032253
# FLAG_EMAIL                                    0.025774
# CNT_FAM_MEMBERS                              -0.008276
# REGION_RATING_CLIENT                         -0.069677
# REGION_RATING_CLIENT_W_CITY                  -0.067715
# HOUR_APPR_PROCESS_START                       0.037512
# REG_REGION_NOT_LIVE_REGION                    0.000339
# REG_REGION_NOT_WORK_REGION                    0.008369
# LIVE_REGION_NOT_WORK_REGION                   0.010243
# REG_CITY_NOT_LIVE_CITY                       -0.010898
# REG_CITY_NOT_WORK_CITY                       -0.012389
# LIVE_CITY_NOT_WORK_CITY                      -0.007763
# EXT_SOURCE_1                                  0.030756
# ...                                                ...
# DEF_30_CNT_SOCIAL_CIRCLE                      0.000169
# OBS_60_CNT_SOCIAL_CIRCLE                      0.001653
# DEF_60_CNT_SOCIAL_CIRCLE                     -0.001623
# DAYS_LAST_PHONE_CHANGE                       -0.041157
# FLAG_DOCUMENT_2                                    NaN
# FLAG_DOCUMENT_3                               0.010259
# FLAG_DOCUMENT_4                               0.005016
# FLAG_DOCUMENT_5                               0.007314
# FLAG_DOCUMENT_6                              -0.023499
# FLAG_DOCUMENT_7                              -0.002408
# FLAG_DOCUMENT_8                               0.019072
# FLAG_DOCUMENT_9                               0.005504
# FLAG_DOCUMENT_10                              0.001208
# FLAG_DOCUMENT_11                             -0.001756
# FLAG_DOCUMENT_12                              0.002198
# FLAG_DOCUMENT_13                              0.009555
# FLAG_DOCUMENT_14                              0.004672
# FLAG_DOCUMENT_15                              0.000964
# FLAG_DOCUMENT_16                              0.001759
# FLAG_DOCUMENT_17                             -0.000133
# FLAG_DOCUMENT_18                             -0.001180
# FLAG_DOCUMENT_19                             -0.002823
# FLAG_DOCUMENT_20                              0.001015
# FLAG_DOCUMENT_21                             -0.003544
# AMT_REQ_CREDIT_BUREAU_HOUR                    0.000107
# AMT_REQ_CREDIT_BUREAU_DAY                    -0.005183
# AMT_REQ_CREDIT_BUREAU_WEEK                   -0.014203
# AMT_REQ_CREDIT_BUREAU_MON                     1.000000
# AMT_REQ_CREDIT_BUREAU_QRT                    -0.007891
# AMT_REQ_CREDIT_BUREAU_YEAR                   -0.005108
#
#                              AMT_REQ_CREDIT_BUREAU_QRT  \
# SK_ID_CURR                                    0.000937
# TARGET                                       -0.002035
# CNT_CHILDREN                                 -0.007717
# AMT_INCOME_TOTAL                              0.004883
# AMT_CREDIT                                    0.016261
# AMT_ANNUITY                                   0.010257
# AMT_GOODS_PRICE                               0.016770
# REGION_POPULATION_RELATIVE                   -0.001102
# DAYS_BIRTH                                   -0.011695
# DAYS_EMPLOYED                                 0.015279
# DAYS_REGISTRATION                            -0.001384
# DAYS_ID_PUBLISH                              -0.006223
# OWN_CAR_AGE                                  -0.017711
# FLAG_MOBIL                                         NaN
# FLAG_EMP_PHONE                               -0.015205
# FLAG_WORK_PHONE                              -0.022954
# FLAG_CONT_MOBILE                              0.006956
# FLAG_PHONE                                   -0.010102
# FLAG_EMAIL                                    0.013238
# CNT_FAM_MEMBERS                              -0.004544
# REGION_RATING_CLIENT                          0.005317
# REGION_RATING_CLIENT_W_CITY                   0.004627
# HOUR_APPR_PROCESS_START                      -0.000676
# REG_REGION_NOT_LIVE_REGION                   -0.002074
# REG_REGION_NOT_WORK_REGION                   -0.004975
# LIVE_REGION_NOT_WORK_REGION                  -0.005677
# REG_CITY_NOT_LIVE_CITY                        0.000870
# REG_CITY_NOT_WORK_CITY                       -0.005350
# LIVE_CITY_NOT_WORK_CITY                      -0.006910
# EXT_SOURCE_1                                 -0.003616
# ...                                                ...
# DEF_30_CNT_SOCIAL_CIRCLE                     -0.001368
# OBS_60_CNT_SOCIAL_CIRCLE                      0.003965
# DEF_60_CNT_SOCIAL_CIRCLE                     -0.000324
# DAYS_LAST_PHONE_CHANGE                       -0.001107
# FLAG_DOCUMENT_2                                    NaN
# FLAG_DOCUMENT_3                               0.009576
# FLAG_DOCUMENT_4                               0.000311
# FLAG_DOCUMENT_5                              -0.004436
# FLAG_DOCUMENT_6                               0.010128
# FLAG_DOCUMENT_7                              -0.000334
# FLAG_DOCUMENT_8                              -0.003131
# FLAG_DOCUMENT_9                              -0.003062
# FLAG_DOCUMENT_10                              0.003399
# FLAG_DOCUMENT_11                             -0.007415
# FLAG_DOCUMENT_12                             -0.000919
# FLAG_DOCUMENT_13                             -0.004656
# FLAG_DOCUMENT_14                             -0.004390
# FLAG_DOCUMENT_15                             -0.001506
# FLAG_DOCUMENT_16                              0.001368
# FLAG_DOCUMENT_17                             -0.001258
# FLAG_DOCUMENT_18                             -0.005298
# FLAG_DOCUMENT_19                             -0.001452
# FLAG_DOCUMENT_20                             -0.000969
# FLAG_DOCUMENT_21                             -0.002161
# AMT_REQ_CREDIT_BUREAU_HOUR                   -0.002583
# AMT_REQ_CREDIT_BUREAU_DAY                    -0.004312
# AMT_REQ_CREDIT_BUREAU_WEEK                   -0.015142
# AMT_REQ_CREDIT_BUREAU_MON                    -0.007891
# AMT_REQ_CREDIT_BUREAU_QRT                     1.000000
# AMT_REQ_CREDIT_BUREAU_YEAR                    0.075589
#
#                              AMT_REQ_CREDIT_BUREAU_YEAR
# SK_ID_CURR                                     0.004486
# TARGET                                         0.019731
# CNT_CHILDREN                                  -0.041729
# AMT_INCOME_TOTAL                               0.011794
# AMT_CREDIT                                    -0.047545
# AMT_ANNUITY                                   -0.011216
# AMT_GOODS_PRICE                               -0.050002
# REGION_POPULATION_RELATIVE                     0.001240
# DAYS_BIRTH                                    -0.071853
# DAYS_EMPLOYED                                  0.049857
# DAYS_REGISTRATION                             -0.024529
# DAYS_ID_PUBLISH                               -0.035155
# OWN_CAR_AGE                                   -0.015134
# FLAG_MOBIL                                          NaN
# FLAG_EMP_PHONE                                -0.049815
# FLAG_WORK_PHONE                               -0.076195
# FLAG_CONT_MOBILE                               0.026851
# FLAG_PHONE                                    -0.031935
# FLAG_EMAIL                                     0.053085
# CNT_FAM_MEMBERS                               -0.028729
# REGION_RATING_CLIENT                           0.011232
# REGION_RATING_CLIENT_W_CITY                    0.010435
# HOUR_APPR_PROCESS_START                       -0.030805
# REG_REGION_NOT_LIVE_REGION                    -0.017165
# REG_REGION_NOT_WORK_REGION                    -0.021684
# LIVE_REGION_NOT_WORK_REGION                   -0.017497
# REG_CITY_NOT_LIVE_CITY                        -0.004762
# REG_CITY_NOT_WORK_CITY                        -0.008123
# LIVE_CITY_NOT_WORK_CITY                       -0.008586
# EXT_SOURCE_1                                   0.006466
# ...                                                 ...
# DEF_30_CNT_SOCIAL_CIRCLE                       0.018605
# OBS_60_CNT_SOCIAL_CIRCLE                       0.033269
# DEF_60_CNT_SOCIAL_CIRCLE                       0.017203
# DAYS_LAST_PHONE_CHANGE                        -0.111234
# FLAG_DOCUMENT_2                                     NaN
# FLAG_DOCUMENT_3                                0.048245
# FLAG_DOCUMENT_4                                0.000277
# FLAG_DOCUMENT_5                               -0.010308
# FLAG_DOCUMENT_6                                0.012553
# FLAG_DOCUMENT_7                                0.003513
# FLAG_DOCUMENT_8                               -0.024134
# FLAG_DOCUMENT_9                               -0.009883
# FLAG_DOCUMENT_10                               0.003215
# FLAG_DOCUMENT_11                              -0.032446
# FLAG_DOCUMENT_12                              -0.002064
# FLAG_DOCUMENT_13                              -0.033311
# FLAG_DOCUMENT_14                              -0.032208
# FLAG_DOCUMENT_15                              -0.017945
# FLAG_DOCUMENT_16                              -0.046358
# FLAG_DOCUMENT_17                              -0.009610
# FLAG_DOCUMENT_18                              -0.046899
# FLAG_DOCUMENT_19                              -0.007367
# FLAG_DOCUMENT_20                              -0.011765
# FLAG_DOCUMENT_21                              -0.005480
# AMT_REQ_CREDIT_BUREAU_HOUR                    -0.004398
# AMT_REQ_CREDIT_BUREAU_DAY                     -0.003188
# AMT_REQ_CREDIT_BUREAU_WEEK                     0.018862
# AMT_REQ_CREDIT_BUREAU_MON                     -0.005108
# AMT_REQ_CREDIT_BUREAU_QRT                      0.075589
# AMT_REQ_CREDIT_BUREAU_YEAR                     1.000000
#
# [106 rows x 106 columns]

# %%
from IPython.core.display import display

display(df_corr.head(), df_corr.tail())
# Out:
#                   SK_ID_CURR    TARGET  CNT_CHILDREN  AMT_INCOME_TOTAL  \
# SK_ID_CURR          1.000000 -0.002148     -0.001272         -0.001750
# TARGET             -0.002148  1.000000      0.019277         -0.003921
# CNT_CHILDREN       -0.001272  0.019277      1.000000          0.012893
# AMT_INCOME_TOTAL   -0.001750 -0.003921      0.012893          1.000000
# AMT_CREDIT         -0.000184 -0.030309      0.002090          0.156154
#
#                   AMT_CREDIT  AMT_ANNUITY  AMT_GOODS_PRICE  \
# SK_ID_CURR         -0.000184    -0.000251        -0.000195
# TARGET             -0.030309    -0.012813        -0.039581
# CNT_CHILDREN        0.002090     0.021478        -0.002028
# AMT_INCOME_TOTAL    0.156154     0.191061         0.159050
# AMT_CREDIT          1.000000     0.769937         0.986975
#
#                   REGION_POPULATION_RELATIVE  DAYS_BIRTH  DAYS_EMPLOYED  \
# SK_ID_CURR                          0.000990   -0.001597       0.001401
# TARGET                             -0.037256    0.078567      -0.045061
# CNT_CHILDREN                       -0.025651    0.331173      -0.239856
# AMT_INCOME_TOTAL                    0.074511    0.027170      -0.064089
# AMT_CREDIT                          0.099497   -0.056325      -0.066039
#
#                              ...              FLAG_DOCUMENT_18  \
# SK_ID_CURR                   ...                      0.000009
# TARGET                       ...                     -0.007826
# CNT_CHILDREN                 ...                      0.003219
# AMT_INCOME_TOTAL             ...                      0.003036
# AMT_CREDIT                   ...                      0.033760
#
#                   FLAG_DOCUMENT_19  FLAG_DOCUMENT_20  FLAG_DOCUMENT_21  \
# SK_ID_CURR                0.000357          0.000683          0.000350
# TARGET                   -0.001578          0.000428          0.003850
# CNT_CHILDREN              0.000572          0.001025         -0.002520
# AMT_INCOME_TOTAL          0.002432          0.000352         -0.000543
# AMT_CREDIT                0.020745          0.029989         -0.016018
#
#                   AMT_REQ_CREDIT_BUREAU_HOUR  AMT_REQ_CREDIT_BUREAU_DAY  \
# SK_ID_CURR                         -0.002708                  -0.002467
# TARGET                              0.000872                   0.002819
# CNT_CHILDREN                       -0.000122                  -0.000109
# AMT_INCOME_TOTAL                    0.000812                   0.002979
# AMT_CREDIT                         -0.003674                   0.003855
#
#                   AMT_REQ_CREDIT_BUREAU_WEEK  AMT_REQ_CREDIT_BUREAU_MON  \
# SK_ID_CURR                          0.002057                   0.000655
# TARGET                              0.000805                  -0.012551
# CNT_CHILDREN                       -0.002276                  -0.010930
# AMT_INCOME_TOTAL                    0.002336                   0.024564
# AMT_CREDIT                         -0.001573                   0.054273
#
#                   AMT_REQ_CREDIT_BUREAU_QRT  AMT_REQ_CREDIT_BUREAU_YEAR
# SK_ID_CURR                         0.000937                    0.004486
# TARGET                            -0.002035                    0.019731
# CNT_CHILDREN                      -0.007717                   -0.041729
# AMT_INCOME_TOTAL                   0.004883                    0.011794
# AMT_CREDIT                         0.016261                   -0.047545
#
# [5 rows x 106 columns]
#                             SK_ID_CURR    TARGET  CNT_CHILDREN  \
# AMT_REQ_CREDIT_BUREAU_DAY    -0.002467  0.002819     -0.000109
# AMT_REQ_CREDIT_BUREAU_WEEK    0.002057  0.000805     -0.002276
# AMT_REQ_CREDIT_BUREAU_MON     0.000655 -0.012551     -0.010930
# AMT_REQ_CREDIT_BUREAU_QRT     0.000937 -0.002035     -0.007717
# AMT_REQ_CREDIT_BUREAU_YEAR    0.004486  0.019731     -0.041729
#
#                             AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# AMT_REQ_CREDIT_BUREAU_DAY           0.002979    0.003855     0.001993
# AMT_REQ_CREDIT_BUREAU_WEEK          0.002336   -0.001573     0.013641
# AMT_REQ_CREDIT_BUREAU_MON           0.024564    0.054273     0.038885
# AMT_REQ_CREDIT_BUREAU_QRT           0.004883    0.016261     0.010257
# AMT_REQ_CREDIT_BUREAU_YEAR          0.011794   -0.047545    -0.011216
#
#                             AMT_GOODS_PRICE  REGION_POPULATION_RELATIVE  \
# AMT_REQ_CREDIT_BUREAU_DAY          0.004319                    0.001142
# AMT_REQ_CREDIT_BUREAU_WEEK        -0.001287                   -0.002273
# AMT_REQ_CREDIT_BUREAU_MON          0.056344                    0.078450
# AMT_REQ_CREDIT_BUREAU_QRT          0.016770                   -0.001102
# AMT_REQ_CREDIT_BUREAU_YEAR        -0.050002                    0.001240
#
#                             DAYS_BIRTH  DAYS_EMPLOYED  \
# AMT_REQ_CREDIT_BUREAU_DAY     0.002668       0.000400
# AMT_REQ_CREDIT_BUREAU_WEEK   -0.001177       0.003137
# AMT_REQ_CREDIT_BUREAU_MON     0.001426      -0.034531
# AMT_REQ_CREDIT_BUREAU_QRT    -0.011695       0.015279
# AMT_REQ_CREDIT_BUREAU_YEAR   -0.071853       0.049857
#
#                                        ...              FLAG_DOCUMENT_18  \
# AMT_REQ_CREDIT_BUREAU_DAY              ...                      0.013948
# AMT_REQ_CREDIT_BUREAU_WEEK             ...                     -0.004269
# AMT_REQ_CREDIT_BUREAU_MON              ...                     -0.001180
# AMT_REQ_CREDIT_BUREAU_QRT              ...                     -0.005298
# AMT_REQ_CREDIT_BUREAU_YEAR             ...                     -0.046899
#
#                             FLAG_DOCUMENT_19  FLAG_DOCUMENT_20  \
# AMT_REQ_CREDIT_BUREAU_DAY           0.001228         -0.000068
# AMT_REQ_CREDIT_BUREAU_WEEK         -0.001134         -0.001680
# AMT_REQ_CREDIT_BUREAU_MON          -0.002823          0.001015
# AMT_REQ_CREDIT_BUREAU_QRT          -0.001452         -0.000969
# AMT_REQ_CREDIT_BUREAU_YEAR         -0.007367         -0.011765
#
#                             FLAG_DOCUMENT_21  AMT_REQ_CREDIT_BUREAU_HOUR  \
# AMT_REQ_CREDIT_BUREAU_DAY          -0.001119                    0.230562
# AMT_REQ_CREDIT_BUREAU_WEEK         -0.000895                    0.004779
# AMT_REQ_CREDIT_BUREAU_MON          -0.003544                    0.000107
# AMT_REQ_CREDIT_BUREAU_QRT          -0.002161                   -0.002583
# AMT_REQ_CREDIT_BUREAU_YEAR         -0.005480                   -0.004398
#
#                             AMT_REQ_CREDIT_BUREAU_DAY  \
# AMT_REQ_CREDIT_BUREAU_DAY                    1.000000
# AMT_REQ_CREDIT_BUREAU_WEEK                   0.214531
# AMT_REQ_CREDIT_BUREAU_MON                   -0.005183
# AMT_REQ_CREDIT_BUREAU_QRT                   -0.004312
# AMT_REQ_CREDIT_BUREAU_YEAR                  -0.003188
#
#                             AMT_REQ_CREDIT_BUREAU_WEEK  \
# AMT_REQ_CREDIT_BUREAU_DAY                     0.214531
# AMT_REQ_CREDIT_BUREAU_WEEK                    1.000000
# AMT_REQ_CREDIT_BUREAU_MON                    -0.014203
# AMT_REQ_CREDIT_BUREAU_QRT                    -0.015142
# AMT_REQ_CREDIT_BUREAU_YEAR                    0.018862
#
#                             AMT_REQ_CREDIT_BUREAU_MON  \
# AMT_REQ_CREDIT_BUREAU_DAY                   -0.005183
# AMT_REQ_CREDIT_BUREAU_WEEK                  -0.014203
# AMT_REQ_CREDIT_BUREAU_MON                    1.000000
# AMT_REQ_CREDIT_BUREAU_QRT                   -0.007891
# AMT_REQ_CREDIT_BUREAU_YEAR                  -0.005108
#
#                             AMT_REQ_CREDIT_BUREAU_QRT  \
# AMT_REQ_CREDIT_BUREAU_DAY                   -0.004312
# AMT_REQ_CREDIT_BUREAU_WEEK                  -0.015142
# AMT_REQ_CREDIT_BUREAU_MON                   -0.007891
# AMT_REQ_CREDIT_BUREAU_QRT                    1.000000
# AMT_REQ_CREDIT_BUREAU_YEAR                   0.075589
#
#                             AMT_REQ_CREDIT_BUREAU_YEAR
# AMT_REQ_CREDIT_BUREAU_DAY                    -0.003188
# AMT_REQ_CREDIT_BUREAU_WEEK                    0.018862
# AMT_REQ_CREDIT_BUREAU_MON                    -0.005108
# AMT_REQ_CREDIT_BUREAU_QRT                     0.075589
# AMT_REQ_CREDIT_BUREAU_YEAR                    1.000000
#
# [5 rows x 106 columns]

# %%
from IPython.core.display import display
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
train_df['NAME_TYPE_SUITE'] = le.fit_transform(train_df['NAME_TYPE_SUITE'])
train_df['NAME_TYPE_SUITE'].value_counts()
df_corr = train_df.corr()
display(df_corr)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-37dbac621080> in <module>()
#       2 from sklearn import preprocessing
#       3 le = preprocessing.LabelEncoder()
# ----> 4 train_df['NAME_TYPE_SUITE'] = le.fit_transform(train_df['NAME_TYPE_SUITE'])
#       5 train_df['NAME_TYPE_SUITE'].value_counts()
#       6 df_corr = train_df.corr()
#
# ~/.pyenv/versions/3.7.0/lib/python3.7/site-packages/sklearn/preprocessing/label.py in fit_transform(self, y)
#     110         """
#     111         y = column_or_1d(y, warn=True)
# --> 112         self.classes_, y = np.unique(y, return_inverse=True)
#     113         return y
#     114
#
# ~/.local/lib/python3.7/site-packages/numpy/lib/arraysetops.py in unique(ar, return_index, return_inverse, return_counts, axis)
#     221     ar = np.asanyarray(ar)
#     222     if axis is None:
# --> 223         return _unique1d(ar, return_index, return_inverse, return_counts)
#     224     if not (-ar.ndim <= axis < ar.ndim):
#     225         raise ValueError('Invalid axis kwarg specified for unique')
#
# ~/.local/lib/python3.7/site-packages/numpy/lib/arraysetops.py in _unique1d(ar, return_index, return_inverse, return_counts)
#     278
#     279     if optional_indices:
# --> 280         perm = ar.argsort(kind='mergesort' if return_index else 'quicksort')
#     281         aux = ar[perm]
#     282     else:
#
# TypeError: '<' not supported between instances of 'float' and 'str'

# %%
import seaborne as sns
import matplotlib.pyplot as plt
sns.heatmap(df_corr,
            vmin=-1.0,
            vmax=1.0,
            center=0,
            annot=True, # True:格子の中に値を表示
            fmt='.1f',
            xticklabels=df_corr.columns.values,
            yticklabels=df_corr.columns.values
           )
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-a1897eb17cb9> in <module>()
# ----> 1 import seaborne as sns
#       2 import matplotlib.pyplot as plt
#       3 sns.heatmap(df_corr,
#       4             vmin=-1.0,
#       5             vmax=1.0,
#
# ModuleNotFoundError: No module named 'seaborne'

# %%
# TARGET との相関関係の低い(絶対値が0.001未満)のcolumnを削除
train_df = train_df.drop(["FLAG_DOCUMENT_2", "FLAG_DOCUMENT_3", "FLAG_DOCUMENT_4", "FLAG_DOCUMENT_5", "FLAG_DOCUMENT_6", "FLAG_DOCUMENT_7", "FLAG_DOCUMENT_8", "FLAG_DOCUMENT_9", "FLAG_DOCUMENT_10", "FLAG_DOCUMENT_11", "FLAG_DOCUMENT_12", "FLAG_DOCUMENT_13", "FLAG_DOCUMENT_14", "FLAG_DOCUMENT_15", "FLAG_DOCUMENT_16", "FLAG_DOCUMENT_17", "FLAG_DOCUMENT_18", "FLAG_DOCUMENT_19", "FLAG_DOCUMENT_20", "FLAG_DOCUMENT_21"], axis=1)
# 欠損率40%以上のcolumnを削除
train_df = train_df.drop(["OWN_CAR_AGE", "APARTMENTS_MEDI", "BASEMENTAREA_MEDI", "YEARS_BEGINEXPLUATATION_MEDI", "YEARS_BUILD_MEDI", "COMMONAREA_MEDI", "ELEVATORS_MEDI", "ENTRANCES_MEDI", "FLOORSMAX_MEDI", "FLOORSMIN_MEDI", "LANDAREA_MEDI", "LIVINGAPARTMENTS_MEDI", "LIVINGAREA_MEDI", "NONLIVINGAPARTMENTS_MEDI", "NONLIVINGAREA_MEDI", "FONDKAPREMONT_MODE", "HOUSETYPE_MODE", "TOTALAREA_MODE", "WALLSMATERIAL_MODE", "EMERGENCYSTATE_MODE"], axis=1)
train_df = train_df.drop(["LANDAREA_AVG", "LIVINGAPARTMENTS_AVG", "LIVINGAREA_AVG", "NONLIVINGAPARTMENTS_AVG", "NONLIVINGAREA_AVG", "APARTMENTS_MODE", "BASEMENTAREA_MODE", "YEARS_BEGINEXPLUATATION_MODE", "YEARS_BUILD_MODE", "COMMONAREA_MODE", "ELEVATORS_MODE", "ENTRANCES_MODE", "FLOORSMAX_MODE", "FLOORSMIN_MODE", "LANDAREA_MODE", "LIVINGAPARTMENTS_MODE", "LIVINGAREA_MODE", "NONLIVINGAPARTMENTS_MODE", "NONLIVINGAREA_MODE"], axis=1)
train_df = train_df.drop(["EXT_SOURCE_1", "APARTMENTS_AVG", "BASEMENTAREA_AVG", "YEARS_BEGINEXPLUATATION_AVG", "YEARS_BUILD_AVG", "COMMONAREA_AVG", "ELEVATORS_AVG", "ENTRANCES_AVG", "FLOORSMAX_AVG", "FLOORSMIN_AVG"], axis=1)
kesson_table(train_df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-80513d83e11f> in <module>()
# 削除
# ----> 2 train_df = train_df.drop(["FLAG_DOCUMENT_2", "FLAG_DOCUMENT_3", "FLAG_DOCUMENT_4", "FLAG_DOCUMENT_5", "FLAG_DOCUMENT_6", "FLAG_DOCUMENT_7", "FLAG_DOCUMENT_8", "FLAG_DOCUMENT_9", "FLAG_DOCUMENT_10", "FLAG_DOCUMENT_11", "FLAG_DOCUMENT_12", "FLAG_DOCUMENT_13", "FLAG_DOCUMENT_14", "FLAG_DOCUMENT_15", "FLAG_DOCUMENT_16", "FLAG_DOCUMENT_17", "FLAG_DOCUMENT_18", "FLAG_DOCUMENT_19", "FLAG_DOCUMENT_20", "FLAG_DOCUMENT_21"], axis=1)
# 欠損率40%以上のcolumnを削除
#       4 train_df = train_df.drop(["OWN_CAR_AGE", "APARTMENTS_MEDI", "BASEMENTAREA_MEDI", "YEARS_BEGINEXPLUATATION_MEDI", "YEARS_BUILD_MEDI", "COMMONAREA_MEDI", "ELEVATORS_MEDI", "ENTRANCES_MEDI", "FLOORSMAX_MEDI", "FLOORSMIN_MEDI", "LANDAREA_MEDI", "LIVINGAPARTMENTS_MEDI", "LIVINGAREA_MEDI", "NONLIVINGAPARTMENTS_MEDI", "NONLIVINGAREA_MEDI", "FONDKAPREMONT_MODE", "HOUSETYPE_MODE", "TOTALAREA_MODE", "WALLSMATERIAL_MODE", "EMERGENCYSTATE_MODE"], axis=1)
#       5 train_df = train_df.drop(["LANDAREA_AVG", "LIVINGAPARTMENTS_AVG", "LIVINGAREA_AVG", "NONLIVINGAPARTMENTS_AVG", "NONLIVINGAREA_AVG", "APARTMENTS_MODE", "BASEMENTAREA_MODE", "YEARS_BEGINEXPLUATATION_MODE", "YEARS_BUILD_MODE", "COMMONAREA_MODE", "ELEVATORS_MODE", "ENTRANCES_MODE", "FLOORSMAX_MODE", "FLOORSMIN_MODE", "LANDAREA_MODE", "LIVINGAPARTMENTS_MODE", "LIVINGAREA_MODE", "NONLIVINGAPARTMENTS_MODE", "NONLIVINGAREA_MODE"], axis=1)
#
# NameError: name 'train_df' is not defined
